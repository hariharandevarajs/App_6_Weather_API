# %% [markdown]
# ## Load DataFrame

# %%
from turtledemo.penrose import sun

import pandas as pd

# %%
df= pd.read_csv(rf"C:\Users\Admin\Downloads\app6_weather_api\app6_weather_api\Jupyter\data-small\TG_STAID000001.txt",skiprows=20,parse_dates=["    DATE"])

# %%
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG
# 0          1   35381 1860-01-01     21      0
# 1          1   35381 1860-01-02     46      0
# 2          1   35381 1860-01-03     31      0
# 3          1   35381 1860-01-04     37      0
# 4          1   35381 1860-01-05     31      0
# ...      ...     ...        ...    ...    ...
# 59316      1   35381 2022-05-27  -9999      9
# 59317      1   35381 2022-05-28  -9999      9
# 59318      1   35381 2022-05-29  -9999      9
# 59319      1   35381 2022-05-30  -9999      9
# 59320      1   35381 2022-05-31  -9999      9
#
# [59321 rows x 5 columns]

# %% [markdown]
# ## Show certain rows

# %%
df[10:20]
# Out:
#     STAID   SOUID       DATE     TG   Q_TG
# 10      1   35381 1860-01-11     -5      0
# 11      1   35381 1860-01-12    -18      0
# 12      1   35381 1860-01-13    -27      0
# 13      1   35381 1860-01-14    -26      0
# 14      1   35381 1860-01-15    -37      0
# 15      1   35381 1860-01-16     -9      0
# 16      1   35381 1860-01-17      7      0
# 17      1   35381 1860-01-18     -6      0
# 18      1   35381 1860-01-19    -16      0
# 19      1   35381 1860-01-20    -19      0

# %% [markdown]
# ## show certain colums

# %%
# df["TG"] if we use this we get error ,bczs in .txt file before sum spces are there so use below

# %%
df.columns
# Out:
# Index(['STAID', ' SOUID', '    DATE', '   TG', ' Q_TG'], dtype='str')

# %%
df["   TG"] #data series , we have only one column , here returns dataframe object
# Out:
# 0          21
# 1          46
# 2          31
# 3          37
# 4          31
#          ...
# 59316   -9999
# 59317   -9999
# 59318   -9999
# 59319   -9999
# 59320   -9999
# Name:    TG, Length: 59321, dtype: int64

# %%
df[['STAID','    DATE','   TG']] # if you want mutiple columns use this list method , here returns data frames
# Out:
#        STAID       DATE     TG
# 0          1 1860-01-01     21
# 1          1 1860-01-02     46
# 2          1 1860-01-03     31
# 3          1 1860-01-04     37
# 4          1 1860-01-05     31
# ...      ...        ...    ...
# 59316      1 2022-05-27  -9999
# 59317      1 2022-05-28  -9999
# 59318      1 2022-05-29  -9999
# 59319      1 2022-05-30  -9999
# 59320      1 2022-05-31  -9999
#
# [59321 rows x 3 columns]

# %%
"""
for this headline , change the cell to markdown , click on the cell then change ,then enter double hash then enter your title like 
for example ## simple statistics
"""
# Out:
# '\nfor this headline , change the cell to markdown , click on the cell then change ,then enter double hash then enter your title like \nfor example ## simple statistics\n'

# %% [markdown]
# ## simple statistic

# %%
df['   TG'].mean() #df['   TG'] - data series or panda series , mean() - means method
# Out:
# np.float64(-991.1500649011311)

# %%
# we got the answer -999 , this is not mean for TG , in the file missing data values are enter like -9999, 
#so we need to filter this and find the actual mean

# %% [markdown]
# ## simple statistics and filtering the data

# %%
df.loc[df['   TG']!=-9999]
# Out:
#        STAID   SOUID       DATE     TG   Q_TG
# 0          1   35381 1860-01-01     21      0
# 1          1   35381 1860-01-02     46      0
# 2          1   35381 1860-01-03     31      0
# 3          1   35381 1860-01-04     37      0
# 4          1   35381 1860-01-05     31      0
# ...      ...     ...        ...    ...    ...
# 53655      1   35381 2006-11-26     80      0
# 53656      1   35381 2006-11-27     70      0
# 53657      1   35381 2006-11-28     71      0
# 53658      1   35381 2006-11-29     63      0
# 53659      1   35381 2006-11-30     84      0
#
# [53103 rows x 5 columns]

# %%
df.loc[df['   TG']!=-9999]['   TG'].mean() /10
# Out:
# np.float64(6.360787526128467)

# %%
#find Max

# %%
df.loc[df['   TG']!=-9999]['   TG'].max() /10
# Out:
# np.float64(26.2)

# %%
#find Min

# %%
df.loc[df['   TG']!=-9999]['   TG'].min() /10
# Out:
# np.float64(-28.8)

# %%
#dd - for duplicate the cell 
#cc - for copy the cell

# %%
df['   TG'].hist() #if use this you get below graph like this , 
#here fake data also present so use filter option
# Out:
# <Axes: >

# %%
#filter the option before get graph
df.loc[df['   TG']!=-9999]['   TG'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ## Get certain cell valuse

# %%
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG
# 0          1   35381 1860-01-01     21      0
# 1          1   35381 1860-01-02     46      0
# 2          1   35381 1860-01-03     31      0
# 3          1   35381 1860-01-04     37      0
# 4          1   35381 1860-01-05     31      0
# ...      ...     ...        ...    ...    ...
# 59316      1   35381 2022-05-27  -9999      9
# 59317      1   35381 2022-05-28  -9999      9
# 59318      1   35381 2022-05-29  -9999      9
# 59319      1   35381 2022-05-30  -9999      9
# 59320      1   35381 2022-05-31  -9999      9
#
# [59321 rows x 5 columns]

# %%
New_df= df.loc[df['   TG']!=-9999]

# %%
New_df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG
# 0          1   35381 1860-01-01     21      0
# 1          1   35381 1860-01-02     46      0
# 2          1   35381 1860-01-03     31      0
# 3          1   35381 1860-01-04     37      0
# 4          1   35381 1860-01-05     31      0
# ...      ...     ...        ...    ...    ...
# 53655      1   35381 2006-11-26     80      0
# 53656      1   35381 2006-11-27     70      0
# 53657      1   35381 2006-11-28     71      0
# 53658      1   35381 2006-11-29     63      0
# 53659      1   35381 2006-11-30     84      0
#
# [53103 rows x 5 columns]

# %%
New_df.loc[New_df['    DATE']=='2006-11-30']
# Out:
#        STAID   SOUID       DATE     TG   Q_TG
# 53659      1   35381 2006-11-30     84      0

# %%
#you can use filter one as well but our example i used df only 
#so dont worry everything is same only

# %%
#df.loc[here conditions comes here]

# %%
#df.loc[df['    DATE']=='2022-05-29']

# %%
df.loc[df['    DATE']=='1860-01-05']['   TG']
# Out:
# 4    31
# Name:    TG, dtype: int64

# %%
df.loc[df['    DATE']=='1860-01-05']['   TG'].squeeze()
# Out:
# np.int64(31)

# %%
df.loc[df['    DATE']=='1860-01-05']['   TG'].squeeze() / 10
# Out:
# np.float64(3.1)

# %%
df.loc[df['   TG']==df['   TG'].max()]['    DATE'].squeeze()
# Out:
# Timestamp('1868-08-16 00:00:00')

# %%
df.loc[3,'   TG'] #here 3 dentoes index
# Out:
# np.int64(37)

# %% [markdown]
# ## Calculate new column out of existing column

# %%
#each time we div by 10 is hardway right so that we create one new column  along with exiting columns

# %%
df["TG"]=df['   TG']/10 #here TG Before no spcae bczs we create new column and named like that thats why

# %%
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG     TG
# 0          1   35381 1860-01-01     21      0    2.1
# 1          1   35381 1860-01-02     46      0    4.6
# 2          1   35381 1860-01-03     31      0    3.1
# 3          1   35381 1860-01-04     37      0    3.7
# 4          1   35381 1860-01-05     31      0    3.1
# ...      ...     ...        ...    ...    ...    ...
# 59316      1   35381 2022-05-27  -9999      9 -999.9
# 59317      1   35381 2022-05-28  -9999      9 -999.9
# 59318      1   35381 2022-05-29  -9999      9 -999.9
# 59319      1   35381 2022-05-30  -9999      9 -999.9
# 59320      1   35381 2022-05-31  -9999      9 -999.9
#
# [59321 rows x 6 columns]

# %%
df["fahrenheit"]=df['TG'] * 9/5 + 32 #here TG Before no spcae bczs we create new column and named like that thats why

# %%
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG     TG  fahrenheit
# 0          1   35381 1860-01-01     21      0    2.1       35.78
# 1          1   35381 1860-01-02     46      0    4.6       40.28
# 2          1   35381 1860-01-03     31      0    3.1       37.58
# 3          1   35381 1860-01-04     37      0    3.7       38.66
# 4          1   35381 1860-01-05     31      0    3.1       37.58
# ...      ...     ...        ...    ...    ...    ...         ...
# 59316      1   35381 2022-05-27  -9999      9 -999.9    -1767.82
# 59317      1   35381 2022-05-28  -9999      9 -999.9    -1767.82
# 59318      1   35381 2022-05-29  -9999      9 -999.9    -1767.82
# 59319      1   35381 2022-05-30  -9999      9 -999.9    -1767.82
# 59320      1   35381 2022-05-31  -9999      9 -999.9    -1767.82
#
# [59321 rows x 7 columns]

# %%
# But here we have values in -9999 so we need change that here we will see how to that add new column there you see nan after implement

# %%
import numpy as np
df["TG0"]=df['   TG'].mask(df['   TG']==-9999,np.nan)
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG     TG  fahrenheit   TG0
# 0          1   35381 1860-01-01     21      0    2.1       35.78  21.0
# 1          1   35381 1860-01-02     46      0    4.6       40.28  46.0
# 2          1   35381 1860-01-03     31      0    3.1       37.58  31.0
# 3          1   35381 1860-01-04     37      0    3.7       38.66  37.0
# 4          1   35381 1860-01-05     31      0    3.1       37.58  31.0
# ...      ...     ...        ...    ...    ...    ...         ...   ...
# 59316      1   35381 2022-05-27  -9999      9 -999.9    -1767.82   NaN
# 59317      1   35381 2022-05-28  -9999      9 -999.9    -1767.82   NaN
# 59318      1   35381 2022-05-29  -9999      9 -999.9    -1767.82   NaN
# 59319      1   35381 2022-05-30  -9999      9 -999.9    -1767.82   NaN
# 59320      1   35381 2022-05-31  -9999      9 -999.9    -1767.82   NaN
#
# [59321 rows x 8 columns]

# %%
# here we calculated values new column

# %%
df["TG"]=df["TG0"]/10
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG   TG  fahrenheit   TG0
# 0          1   35381 1860-01-01     21      0  2.1       35.78  21.0
# 1          1   35381 1860-01-02     46      0  4.6       40.28  46.0
# 2          1   35381 1860-01-03     31      0  3.1       37.58  31.0
# 3          1   35381 1860-01-04     37      0  3.7       38.66  37.0
# 4          1   35381 1860-01-05     31      0  3.1       37.58  31.0
# ...      ...     ...        ...    ...    ...  ...         ...   ...
# 59316      1   35381 2022-05-27  -9999      9  NaN    -1767.82   NaN
# 59317      1   35381 2022-05-28  -9999      9  NaN    -1767.82   NaN
# 59318      1   35381 2022-05-29  -9999      9  NaN    -1767.82   NaN
# 59319      1   35381 2022-05-30  -9999      9  NaN    -1767.82   NaN
# 59320      1   35381 2022-05-31  -9999      9  NaN    -1767.82   NaN
#
# [59321 rows x 8 columns]

# %%
df["fahrenheit"]=df['TG'] * 9/5 + 32 #here TG Before no spcae bczs we create new column and named like that thats why
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG   TG  fahrenheit   TG0
# 0          1   35381 1860-01-01     21      0  2.1       35.78  21.0
# 1          1   35381 1860-01-02     46      0  4.6       40.28  46.0
# 2          1   35381 1860-01-03     31      0  3.1       37.58  31.0
# 3          1   35381 1860-01-04     37      0  3.7       38.66  37.0
# 4          1   35381 1860-01-05     31      0  3.1       37.58  31.0
# ...      ...     ...        ...    ...    ...  ...         ...   ...
# 59316      1   35381 2022-05-27  -9999      9  NaN         NaN   NaN
# 59317      1   35381 2022-05-28  -9999      9  NaN         NaN   NaN
# 59318      1   35381 2022-05-29  -9999      9  NaN         NaN   NaN
# 59319      1   35381 2022-05-30  -9999      9  NaN         NaN   NaN
# 59320      1   35381 2022-05-31  -9999      9  NaN         NaN   NaN
#
# [59321 rows x 8 columns]

# %% [markdown]
# ## Plotting

# %%
df["fahrenheit"].hist()
# Out:
# <Axes: >

# %%
df.plot(x='    DATE',y='TG',figsize=(15,3))
# Out:
# <Axes: xlabel='    DATE'>

# %%
df[100:1000].plot(x='    DATE',y='TG',figsize=(15,3))
# Out:
# <Axes: xlabel='    DATE'>

# %%
import pandas as pd
df = pd.read_csv(rf"C:\Users\devap\Downloads\app6_weather_api\dictionary.csv")
df
# Out:
#                             word  \
# 0      abandoned industrial site
# 1              abandoned vehicle
# 2                 abiotic factor
# 3                    access road
# 4              access to the sea
# ...                          ...
# 49532                     casing
# 49533                     facing
# 49534                     lining
# 49535         assumption of Mary
# 49536               auscultation
#
#                                               definition
# 0      Site that cannot be used for any purpose, bein...
# 1      A vehicle that has been discarded in the envir...
# 2      Physical, chemical and other non-living enviro...
# 3      Any street or narrow stretch of paved surface ...
# 4      The ability to bring goods to and from a port ...
# ...                                                  ...
# 49532  Something put around something else, usually i...
# 49533  Something put around something else, usually i...
# ...

# %%
df.loc[df['word']=='sun']['definition'].squeeze()
# Out:
# '1. Any star, especially when seen as the centre of any single solar system.\n2. The particular star at the centre of our solar system, from which the Earth gets light and heat.\n'

# %%
import pandas as pd
staions=pd.read_csv("data-small/stations.txt",skiprows=17)
# staions
staions.loc[int(staions['STAID'])==3]['STANAME                                 '].squeeze()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 4
#       1 import pandas as pd
#       2 staions=pd.read_csv("data-small/stations.txt",skiprows=17)
#       3 # staions
# ----> 4 staions.loc[int(staions['STAID'])==3]['STANAME                                 '].squeeze()
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'Series'
